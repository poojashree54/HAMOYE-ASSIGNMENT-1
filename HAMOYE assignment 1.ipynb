# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:/Users/HP/Downloads/FoodBalanceSheets_E_Africa_NOFLAG.csv",encoding='latin-1')

# %%
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
df.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
df['Y2014'].sum()
# Out:
# 7965086.130000001

# %%
df.mean()
# Out:
# Area Code        134.265576
# Item Code       2687.176706
# Element Code    3814.856456
# Y2014            134.196282
# Y2015            135.235966
# Y2016            136.555222
# Y2017            140.917765
# Y2018            143.758381
# dtype: float64

# %%
df.std()
# Out:
# Area Code         72.605709
# Item Code        146.055739
# Element Code    2212.007033
# Y2014           1567.663696
# Y2015           1603.403984
# Y2016           1640.007194
# Y2017           1671.862359
# Y2018           1710.782658
# dtype: float64

# %%
corr=df['Element Code'].corr(method='pearson', min_periods=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-056a8e154bb7> in <module>
# ----> 1 corr=df['Element Code'].corr(method='pearson', min_periods=1)
#
# TypeError: corr() missing 1 required positional argument: 'other'

# %%
df['Area'].unique()
# Out:
# array(['Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso',
#        'Cabo Verde', 'Cameroon', 'Central African Republic', 'Chad',
#        'Comoros', 'Congo', "Côte d'Ivoire", 'Djibouti', 'Egypt',
#        'Eswatini', 'Ethiopia', 'Ethiopia PDR', 'Gabon', 'Gambia', 'Ghana',
#        'Guinea', 'Guinea-Bissau', 'Kenya', 'Lesotho', 'Liberia',
#        'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius',
#        'Morocco', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Rwanda',
#        'Sao Tome and Principe', 'Senegal', 'Seychelles', 'Sierra Leone',
#        'South Africa', 'Sudan', 'Sudan (former)', 'Togo', 'Tunisia',
#        'Uganda', 'United Republic of Tanzania', 'Zambia', 'Zimbabwe'],
#       dtype=object)

# %%
grouped = df.groupby(["Y2018", "Element"],sort=False).sum()

# %%
grouped
# Out:
#                                                  Area Code  Item Code  \
# Y2018    Element
# 42228.00 Total Population - Both sexes                   4       2501
# 0.00     Domestic supply quantity                   194906    3917812
# 3322.00  Food supply (kcal/capita/day)                   4       2901
# 91.83    Protein supply quantity (g/capita/day)          4       2901
# 77.28    Fat supply quantity (g/capita/day)              4       2901
# ...                                                    ...        ...
# 20.79    Import Quantity                               181       2763
# 19.41    Domestic supply quantity                      181       2763
# 18.76    Food                                          181       2763
# 0.99     Domestic supply quantity                      181       2764
#          Food                                          181       2764
#
#                                                  Element Code     Y2014  \
# Y2018    Element
# ...

# %%
 df.groupby(["Y2014"]).sum()
# Out:
#            Area Code  Item Code  Element Code     Y2015     Y2016     Y2017  \
# Y2014
# -1796.0          159       2657          5072     -73.0     -12.0       0.0
# -1631.0          159       2924          5072       6.0     -77.0    -689.0
# -849.0           266       5444         10340   -1118.0   -1119.0   -1200.0
# -838.0           184       2907          5072    -827.0    -679.0    -538.0
# -685.0           143       2905          5072    3418.0   -3225.0     689.0
# ...              ...        ...           ...       ...       ...       ...
#  90425.0          59       2501           511   92443.0   94447.0   96443.0
#  98094.0         238       2501           511  100835.0  103603.0  106400.0
#  108756.0        159       2907          5301  110798.0  116483.0  112625.0
#  109593.0        159       2907          5511  111663.0  119330.0  117702.0
#  176405.0        159       2501           511  181137.0  185960.0  190873.0
#
#               Y2018
# Y2014
# ...

# %%
 df.groupby(["Element"],sort=True).sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %%
 df.groupby(["Area","Element"]).sum()
# Out:
#                                                  Area Code  Item Code  \
# Area     Element
# Algeria  Domestic supply quantity                      464     311204
#          Export Quantity                               392     264011
#          Fat supply quantity (g/capita/day)            432     291489
#          Feed                                           88      58967
#          Food                                          420     282744
# ...                                                    ...        ...
# Zimbabwe Protein supply quantity (g/capita/day)      20453     304589
#          Residuals                                   18824     277476
#          Seed                                         3439      50560
#          Stock Variation                             17195     254157
#          Total Population - Both sexes                 181       2501
#
#                                                  Element Code     Y2014  \
# Area     Element
# ...

# %%
df.corr()
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...
